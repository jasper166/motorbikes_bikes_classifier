# %% [markdown]
# <a href="https://colab.research.google.com/github/jasper166/motorbikes_bikes_classifier/blob/main/motorcycles_bicycles_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jasper166/motorbikes_bikes_classifier.git
# Out:
# Cloning into 'motorbikes_bikes_classifier'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 140 (delta 32), reused 118 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (140/140), 809.73 KiB | 2.57 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
cd /content/motorbikes_bikes_classifier
# Out:
# /content/motorbikes_bikes_classifier

# %%
# !mkdir checkpoint

import gdown
gdown.download(id = '1Ko1iJ_bkjuzca7ZDTid0G0iDvwVmdhYm', output = 'checkpoint/optimized.pth', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Ko1iJ_bkjuzca7ZDTid0G0iDvwVmdhYm
# From (redirected): https://drive.google.com/uc?id=1Ko1iJ_bkjuzca7ZDTid0G0iDvwVmdhYm&confirm=t&uuid=9233e38a-d7b2-4903-a58e-1c0bdbc6f93c
# To: /content/motorbikes_bikes_classifier/checkpoint/optimized.pth
# 100%|██████████| 1.39G/1.39G [00:29<00:00, 47.3MB/s]
# 'checkpoint/optimized.pth'

# %%
# !python train.py --data_root datasets/train
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.10/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /content/motorbikes_bikes_classifier/models/convnext.py:164: UserWarning: Overwriting convnext_tiny in registry with models.convnext.convnext_tiny. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   def convnext_tiny(pretrained=False, in_22k=False,args = None, **kwargs):
# ...

# %%
# !rm -rf /content/motorbikes_bikes_classifier

# %%
# !mkdir image_test
import gdown
gdown.download(id = '1Bpfp9KLL9mbaohVnjAuRQdrPZDgAJb0l', output = 'image_test/bicycle.jpg', quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Bpfp9KLL9mbaohVnjAuRQdrPZDgAJb0l
# To: /content/motorbikes_bikes_classifier/image_test/bicycle.jpg
# 100%|██████████| 121k/121k [00:00<00:00, 4.04MB/s]
# 'image_test/bicycle.jpg'

# %%
from tensorflow import keras
from keras.preprocessing import image
import matplotlib.pyplot as plt

path_image = "image_test/" + "yamaha.jpg"
img = image.load_img(path_image, target_size=(224,224))
plt.imshow(img)
plt.axis('off')

# !python predict.py --image image_test/yamaha.jpg --checkpoint_dir checkpoint/optimized.pth --dir_root datasets
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.10/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /content/motorbikes_bikes_classifier/models/convnext.py:164: UserWarning: Overwriting convnext_tiny in registry with models.convnext.convnext_tiny. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   def convnext_tiny(pretrained=False, in_22k=False,args = None, **kwargs):
# ...
